# %%
# !pip install deap
# Out:
# Requirement already satisfied: deap in /usr/local/lib/python3.10/dist-packages (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deap) (1.26.4)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from deap import base, creator, tools, algorithms
import random
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
# Set random seed for reproducibility
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# Define multi-objective fitness to maximize accuracy, minimize complexity, and training time
creator.create("FitnessMulti", base.Fitness, weights=(1.0, -1.0, -1.0))  # Maximize accuracy, minimize complexity & time
creator.create("Individual", list, fitness=creator.FitnessMulti)

print("Environment setup complete.")
# Out:
# Environment setup complete.

# %%
def load_data():
    print("Loading and preprocessing CIFAR-10 dataset...")
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()

    # Normalize pixel values to [0, 1]
    x_train = x_train.astype('float32') / 255.0
    x_test = x_test.astype('float32') / 255.0

    # Convert labels to one-hot encoding
    y_train = to_categorical(y_train, 10)
    y_test = to_categorical(y_test, 10)

    # Split training data into training and validation sets
    val_split = 0.1
    num_sample = 2000
    x_train = x_train[:num_sample]
    y_train = y_train[:num_sample]
    val_size = int(len(x_train) * val_split)
    x_val, y_val = x_train[:val_size], y_train[:val_size]
    x_train, y_train = x_train[val_size:], y_train[val_size:]

    return (x_train, y_train), (x_val, y_val), (x_test, y_test)

# Load data
(x_train, y_train), (x_val, y_val), (x_test, y_test) = load_data()
print("Data preparation complete.")
# Out:
# Loading and preprocessing CIFAR-10 dataset...
# Data preparation complete.

# %%
print("Training data shape:", x_train.shape)
print("Validation data shape:", x_val.shape)
print("Test data shape:", x_test.shape)
# Out:
# Training data shape: (1800, 32, 32, 3)
# Validation data shape: (200, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)

# %%
def generate_individual():
    layers = []
    num_layers = random.randint(2, 4)  # Random number of layers
    for _ in range(num_layers):
        layer_type = random.choice(['conv', 'dense'])
        if layer_type == 'conv':
            layers.append({
                'type': 'conv',
                'filters': random.choice([16, 32, 64, 128]),
                'activation': random.choice(['relu', 'tanh'])
            })
        elif layer_type == 'dense':
            layers.append({
                'type': 'dense',
                'units': random.choice([64, 128, 256, 512]),
                'activation': random.choice(['relu', 'tanh'])
            })
    return layers

# Register individual and population in the DEAP toolbox
toolbox = base.Toolbox()
toolbox.register("individual", tools.initIterate, creator.Individual, generate_individual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

print("Initial population generation complete.")
# Out:
# Initial population generation complete.

# %%
def create_cnn(architecture):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(32, 32, 3)))  # Input layer for CIFAR-10

    added_flatten = False
    for layer in architecture:
        if layer['type'] == 'conv' and not added_flatten:
            model.add(tf.keras.layers.Conv2D(layer['filters'], (3, 3), activation=layer['activation'], padding='same'))
            model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
        elif layer['type'] == 'dense':
            if not added_flatten:
                model.add(tf.keras.layers.Flatten())
                added_flatten = True
            model.add(tf.keras.layers.Dense(layer['units'], activation=layer['activation']))

    if not added_flatten:
        model.add(tf.keras.layers.Flatten())

    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    return model

evaluation_counter = 1

def evaluate_cnn(individual):
    global evaluation_counter  # Use global counter to label individuals
    print(f"Evaluating individual {evaluation_counter}: {individual}")
    evaluation_counter += 1

    model = create_cnn(individual)
    start_time = time.time()

    # Train the model on a small subset for quicker evaluation
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val),
                        epochs=3, batch_size=32, verbose=False)
    accuracy = model.evaluate(x_val, y_val, verbose=0)[1]
    model_complexity = model.count_params()
    training_time = time.time() - start_time

    print(f"Individual {evaluation_counter - 1} Results: Accuracy: {accuracy}, Model Complexity: {model_complexity}, Training Time: {training_time}")
    return accuracy, model_complexity, training_time

# Register evaluation function in DEAP toolbox
toolbox.register("evaluate", evaluate_cnn)

# %%
def lexicase_selection(population, k):
    selected = []
    for _ in range(k):
        candidates = population[:]
        random.shuffle(candidates)
        objectives = list(range(len(population[0].fitness.values)))
        random.shuffle(objectives)
        for obj in objectives:
            best_candidates = [c for c in candidates if c.fitness.values[obj] == max(c.fitness.values[obj] for c in candidates)]
            print("Best candidates:", best_candidates)  # Print best candidates for debugging
            candidates = best_candidates
            if len(candidates) == 1:
                break
        selected.append(candidates[0])
    return selected

# Register selection methods without specifying k
toolbox.register("select_tournament", tools.selTournament, tournsize=3)
toolbox.register("select_lexicase", lexicase_selection)

print("Lexicase selection setup complete.")
# Out:
# Lexicase selection setup complete.

# %%
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutShuffleIndexes, indpb=0.2)
def apply_crossover_and_mutation(offspring, cxpb, mutpb):
    print("\n--- Applying Crossover and Mutation ---")

    # Apply crossover
    for i, (child1, child2) in enumerate(zip(offspring[::2], offspring[1::2]), start=1):
        if random.random() < cxpb:
            print(f"\nCrossover Pair {i}:")
            print(f"  Before Crossover:")
            print(f"    Child 1: {child1}")
            print(f"    Child 2: {child2}")

            # Perform crossover
            toolbox.mate(child1, child2)

            print(f"  After Crossover:")
            print(f"    Child 1: {child1}")
            print(f"    Child 2: {child2}")

            # Reset fitness after crossover
            del child1.fitness.values
            del child2.fitness.values

    # Apply mutation
    for i, mutant in enumerate(offspring, start=1):
        if random.random() < mutpb:
            print(f"\nMutation for Offspring {i}:")
            print(f"  Before Mutation: {mutant}")

            # Perform mutation
            toolbox.mutate(mutant)

            print(f"  After Mutation: {mutant}")

            # Reset fitness after mutation
            del mutant.fitness.values

    print("\n--- Crossover and Mutation Complete ---")

# %%
8ul
    global evaluation_counter  # Use global evaluation counter
    population = toolbox.population(n=pop_size)
    fitness_log = []

    for gen in range(n_gen):
        print(f"\n-- Generation {gen} --")

        # Reset evaluation counter at the start of each generation
        evaluation_counter = 1

        # Evaluate fitness of the population
        fitnesses = list(map(toolbox.evaluate, population))
        for ind, fit in zip(population, fitnesses):
            ind.fitness.values = fit

        # Calculate average fitness for logging
        avg_fitness = np.mean([ind.fitness.values[0] for ind in population])
        fitness_log.append(avg_fitness)
        print(f"Average Fitness: {avg_fitness}")

        # Selection of parents
        #if gen < n_gen // 2:
        #    selected_parents = toolbox.select_tournament(population, len(population))
        #    print(f"Tournament selection in Generation {gen}:")
        #else:
        #    selected_parents = toolbox.select_lexicase(population, len(population))
        #    print(f"Lexicase selection in Generation {gen}:")

        # Selection of parents (alternating between tournament and lexicase selection)
        if gen % 2 == 0:
            selected_parents = toolbox.select_tournament(population, len(population))
            print(f"Tournament selection in Generation {gen}:")
        else:
            selected_parents = toolbox.select_lexicase(population, len(population))
            print(f"Lexicase selection in Generation {gen}:")



        # Selection of parents
        #if gen < (3 * n_gen) // 10:
        #    selected_parents = toolbox.select_tournament(population, len(population))
        #    print(f"Tournament selection in Generation {gen}:")
        #else:
        #    selected_parents = toolbox.select_lexicase(population, len(population))
        #    print(f"Lexicase selection in Generation {gen}:")


        # Print selected parents' architectures and fitness with parent ID
        for idx, parent in enumerate(selected_parents):
            print(f"Selected Parent {idx + 1}: Architecture: {parent}, Fitness: {parent.fitness.values}")

        # Clone the selected parents to create offspring
        offspring = list(map(toolbox.clone, selected_parents))

        # Apply crossover and mutation to the offspring
        apply_crossover_and_mutation(offspring, cxpb, mutpb)

        # Replace the old population with the new offspring
        population[:] = offspring

    # Plotting the fitness progression
    plt.plot(range(n_gen), fitness_log)
    plt.xlabel('Generation')
    plt.ylabel('Average Fitness')
    plt.title('Evolutionary Progress')
    plt.show()

    # Return the best individual found
    best_ind = tools.selBest(population, 1)[0]
    return best_ind

# Run the modified evolutionary algorithm
print("Iterative evolution process setup complete.")
best_architecture = evolutionary_algorithm()
print("Best architecture found:", best_architecture)
# Out:
# Iterative evolution process setup complete.
#
# -- Generation 0 --
# Evaluating individual 1: [{'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'conv', 'filters': 32, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'relu'}]
# Individual 1 Results: Accuracy: 0.25, Model Complexity: 12682, Training Time: 23.509973526000977
# Evaluating individual 2: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'tanh'}]
# Individual 2 Results: Accuracy: 0.375, Model Complexity: 526154, Training Time: 4.424819231033325
# Evaluating individual 3: [{'type': 'dense', 'units': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'tanh'}, {'type': 'conv', 'filters': 32, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]
# Individual 3 Results: Accuracy: 0.2849999964237213, Model Complexity: 215882, Training Time: 6.416443586349487
# Evaluating individual 4: [{'type': 'dense', 'units': 256, 'activation': 'tanh'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}]
# Individual 4 Results: Accuracy: 0.19499999284744263, Model Complexity: 789258, Training Time: 3.249478578567505
# Evaluating individual 5: [{'type': 'conv', 'filters': 64, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 64, 'activation': 'relu'}]
# Individual 5 Results: Accuracy: 0.29499998688697815, Model Complexity: 30554, Training Time: 6.200454950332642
# Evaluating individual 6: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 6 Results: Accuracy: 0.38999998569488525, Model Complexity: 8395018, Training Time: 5.627822399139404
# Evaluating individual 7: [{'type': 'dense', 'units': 128, 'activation': 'tanh'}, {'type': 'conv', 'filters': 32, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'tanh'}]
# Individual 7 Results: Accuracy: 0.20999999344348907, Model Complexity: 394634, Training Time: 3.162036418914795
# Evaluating individual 8: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 8 Results: Accuracy: 0.41999998688697815, Model Complexity: 275994, Training Time: 11.84314775466919
# Evaluating individual 9: [{'type': 'dense', 'units': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 512, 'activation': 'relu'}]
# Individual 9 Results: Accuracy: 0.20499999821186066, Model Complexity: 464522, Training Time: 4.212578296661377
# Evaluating individual 10: [{'type': 'conv', 'filters': 32, 'activation': 'tanh'}, {'type': 'dense', 'units': 512, 'activation': 'tanh'}, {'type': 'conv', 'filters': 32, 'activation': 'tanh'}]
# Individual 10 Results: Accuracy: 0.4099999964237213, Model Complexity: 4200842, Training Time: 7.21379542350769
# Evaluating individual 11: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}]
# Individual 11 Results: Accuracy: 0.41499999165534973, Model Complexity: 100938, Training Time: 5.402074813842773
# Evaluating individual 12: [{'type': 'dense', 'units': 512, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 64, 'activation': 'tanh'}]
# Individual 12 Results: Accuracy: 0.1550000011920929, Model Complexity: 1606858, Training Time: 6.792636394500732
# Evaluating individual 13: [{'type': 'conv', 'filters': 128, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'relu'}]
# Individual 13 Results: Accuracy: 0.36500000953674316, Model Complexity: 4215818, Training Time: 7.9258692264556885
# Evaluating individual 14: [{'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 14 Results: Accuracy: 0.33000001311302185, Model Complexity: 281866, Training Time: 6.623579740524292
# Evaluating individual 15: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'dense', 'units': 64, 'activation': 'relu'}]
# Individual 15 Results: Accuracy: 0.38999998569488525, Model Complexity: 263306, Training Time: 6.591501712799072
# Average Fitness: 0.312666662534078
# Tournament selection in Generation 0:
# Selected Parent 1: Architecture: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'tanh'}], Fitness: (0.375, 526154.0, 4.424819231033325)
# Selected Parent 2: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 275994.0, 11.84314775466919)
# Selected Parent 3: Architecture: [{'type': 'dense', 'units': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'tanh'}, {'type': 'conv', 'filters': 32, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}], Fitness: (0.2849999964237213, 215882.0, 6.416443586349487)
# Selected Parent 4: Architecture: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'dense', 'units': 64, 'activation': 'relu'}], Fitness: (0.38999998569488525, 263306.0, 6.591501712799072)
# Selected Parent 5: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 275994.0, 11.84314775466919)
# Selected Parent 6: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 275994.0, 11.84314775466919)
# Selected Parent 7: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'relu'}], Fitness: (0.36500000953674316, 4215818.0, 7.9258692264556885)
# Selected Parent 8: Architecture: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}], Fitness: (0.41499999165534973, 100938.0, 5.402074813842773)
# Selected Parent 9: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.38999998569488525, 8395018.0, 5.627822399139404)
# Selected Parent 10: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 275994.0, 11.84314775466919)
# Selected Parent 11: Architecture: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}], Fitness: (0.41499999165534973, 100938.0, 5.402074813842773)
# Selected Parent 12: Architecture: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}], Fitness: (0.41499999165534973, 100938.0, 5.402074813842773)
# Selected Parent 13: Architecture: [{'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'conv', 'filters': 32, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'relu'}], Fitness: (0.25, 12682.0, 23.509973526000977)
# Selected Parent 14: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.38999998569488525, 8395018.0, 5.627822399139404)
# Selected Parent 15: Architecture: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'tanh'}], Fitness: (0.375, 526154.0, 4.424819231033325)
#
# --- Applying Crossover and Mutation ---
#
# Crossover Pair 1:
#   Before Crossover:
#     Child 1: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'tanh'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Crossover:
#     Child 1: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#
# Crossover Pair 2:
#   Before Crossover:
#     Child 1: [{'type': 'dense', 'units': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'tanh'}, {'type': 'conv', 'filters': 32, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]
#     Child 2: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'dense', 'units': 64, 'activation': 'relu'}]
#   After Crossover:
#     Child 1: [{'type': 'dense', 'units': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 32, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]
#     Child 2: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'tanh'}]
#
# Crossover Pair 3:
#   Before Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#
# Crossover Pair 6:
#   Before Crossover:
#     Child 1: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}]
#   After Crossover:
#     Child 1: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}]
#
# Mutation for Offspring 6:
#   Before Mutation: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Mutation: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#
# --- Crossover and Mutation Complete ---
#
# -- Generation 1 --
# Evaluating individual 1: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]
# Individual 1 Results: Accuracy: 0.36500000953674316, Model Complexity: 13018, Training Time: 4.178038597106934
# Evaluating individual 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 2 Results: Accuracy: 0.41999998688697815, Model Complexity: 2134666, Training Time: 6.8242998123168945
# Evaluating individual 3: [{'type': 'dense', 'units': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 32, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]
# Individual 3 Results: Accuracy: 0.23000000417232513, Model Complexity: 201482, Training Time: 3.5631892681121826
# Evaluating individual 4: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'tanh'}]
# Individual 4 Results: Accuracy: 0.39500001072883606, Model Complexity: 1051850, Training Time: 6.682819366455078
# Evaluating individual 5: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 5 Results: Accuracy: 0.41999998688697815, Model Complexity: 275994, Training Time: 7.05683159828186
# Evaluating individual 6: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 6 Results: Accuracy: 0.36500000953674316, Model Complexity: 275994, Training Time: 4.781840562820435
# Evaluating individual 7: [{'type': 'conv', 'filters': 128, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'relu'}]
# Individual 7 Results: Accuracy: 0.3499999940395355, Model Complexity: 4215818, Training Time: 4.622520208358765
# Evaluating individual 8: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}]
# Individual 8 Results: Accuracy: 0.4050000011920929, Model Complexity: 100938, Training Time: 3.9653830528259277
# Evaluating individual 9: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 9 Results: Accuracy: 0.39500001072883606, Model Complexity: 8395018, Training Time: 4.564208507537842
# Evaluating individual 10: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 10 Results: Accuracy: 0.4350000023841858, Model Complexity: 275994, Training Time: 4.333032131195068
# Evaluating individual 11: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}]
# Individual 11 Results: Accuracy: 0.4000000059604645, Model Complexity: 100938, Training Time: 3.77474308013916
# Evaluating individual 12: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'relu'}]
# Individual 12 Results: Accuracy: 0.38999998569488525, Model Complexity: 100938, Training Time: 6.620014905929565
# Evaluating individual 13: [{'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'conv', 'filters': 32, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'relu'}]
# Individual 13 Results: Accuracy: 0.22499999403953552, Model Complexity: 12682, Training Time: 4.4480791091918945
# Evaluating individual 14: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 14 Results: Accuracy: 0.39500001072883606, Model Complexity: 8395018, Training Time: 4.631834030151367
# Evaluating individual 15: [{'type': 'conv', 'filters': 16, 'activation': 'relu'}, {'type': 'dense', 'units': 128, 'activation': 'tanh'}]
# Individual 15 Results: Accuracy: 0.39500001072883606, Model Complexity: 526154, Training Time: 4.20589017868042
# Average Fitness: 0.3723333348830541
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Lexicase selection in Generation 1:
# Selected Parent 1: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4350000023841858, 275994.0, 4.333032131195068)
# Selected Parent 2: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.39500001072883606, 8395018.0, 4.631834030151367)
# Selected Parent 3: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4350000023841858, 275994.0, 4.333032131195068)
# Selected Parent 4: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4350000023841858, 275994.0, 4.333032131195068)
# Selected Parent 5: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4350000023841858, 275994.0, 4.333032131195068)
# Selected Parent 6: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 275994.0, 7.05683159828186)
# Selected Parent 7: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.39500001072883606, 8395018.0, 4.631834030151367)
# Selected Parent 8: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4350000023841858, 275994.0, 4.333032131195068)
# Selected Parent 9: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4350000023841858, 275994.0, 4.333032131195068)
# Selected Parent 10: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4350000023841858, 275994.0, 4.333032131195068)
# Selected Parent 11: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.39500001072883606, 8395018.0, 4.631834030151367)
# Selected Parent 12: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4350000023841858, 275994.0, 4.333032131195068)
# Selected Parent 13: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4350000023841858, 275994.0, 4.333032131195068)
# Selected Parent 14: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4350000023841858, 275994.0, 4.333032131195068)
# Selected Parent 15: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 275994.0, 7.05683159828186)
#
# --- Applying Crossover and Mutation ---
#
# Crossover Pair 1:
#   Before Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]
#
# Mutation for Offspring 12:
#   Before Mutation: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Mutation: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#
# --- Crossover and Mutation Complete ---
#
# -- Generation 2 --
# Evaluating individual 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 1 Results: Accuracy: 0.3499999940395355, Model Complexity: 4264714, Training Time: 5.6740641593933105
# Evaluating individual 2: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]
# Individual 2 Results: Accuracy: 0.36500000953674316, Model Complexity: 32282, Training Time: 6.9103028774261475
# Evaluating individual 3: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 3 Results: Accuracy: 0.41499999165534973, Model Complexity: 275994, Training Time: 4.247627019882202
# Evaluating individual 4: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 4 Results: Accuracy: 0.39500001072883606, Model Complexity: 275994, Training Time: 5.022054195404053
# Evaluating individual 5: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 5 Results: Accuracy: 0.4000000059604645, Model Complexity: 275994, Training Time: 4.2418129444122314
# Evaluating individual 6: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 6 Results: Accuracy: 0.39500001072883606, Model Complexity: 275994, Training Time: 4.173845052719116
# Evaluating individual 7: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 7 Results: Accuracy: 0.39500001072883606, Model Complexity: 8395018, Training Time: 4.665268659591675
# Evaluating individual 8: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 8 Results: Accuracy: 0.39500001072883606, Model Complexity: 275994, Training Time: 4.202924728393555
# Evaluating individual 9: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 9 Results: Accuracy: 0.4050000011920929, Model Complexity: 275994, Training Time: 4.281090497970581
# Evaluating individual 10: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 10 Results: Accuracy: 0.3700000047683716, Model Complexity: 275994, Training Time: 5.060096502304077
# Evaluating individual 11: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 11 Results: Accuracy: 0.38999998569488525, Model Complexity: 8395018, Training Time: 4.467099666595459
# Evaluating individual 12: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 12 Results: Accuracy: 0.39500001072883606, Model Complexity: 275994, Training Time: 4.302081823348999
# Evaluating individual 13: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 13 Results: Accuracy: 0.4050000011920929, Model Complexity: 275994, Training Time: 4.824419260025024
# Evaluating individual 14: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 14 Results: Accuracy: 0.38499999046325684, Model Complexity: 275994, Training Time: 4.277230501174927
# Evaluating individual 15: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 15 Results: Accuracy: 0.38999998569488525, Model Complexity: 275994, Training Time: 4.753033876419067
# Average Fitness: 0.3900000015894572
# Tournament selection in Generation 2:
# Selected Parent 1: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41499999165534973, 275994.0, 4.247627019882202)
# Selected Parent 2: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41499999165534973, 275994.0, 4.247627019882202)
# Selected Parent 3: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4050000011920929, 275994.0, 4.281090497970581)
# Selected Parent 4: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.39500001072883606, 8395018.0, 4.665268659591675)
# Selected Parent 5: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.38999998569488525, 8395018.0, 4.467099666595459)
# Selected Parent 6: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41499999165534973, 275994.0, 4.247627019882202)
# Selected Parent 7: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41499999165534973, 275994.0, 4.247627019882202)
# Selected Parent 8: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4000000059604645, 275994.0, 4.2418129444122314)
# Selected Parent 9: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.39500001072883606, 275994.0, 4.173845052719116)
# Selected Parent 10: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4050000011920929, 275994.0, 4.824419260025024)
# Selected Parent 11: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4000000059604645, 275994.0, 4.2418129444122314)
# Selected Parent 12: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4050000011920929, 275994.0, 4.824419260025024)
# Selected Parent 13: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4000000059604645, 275994.0, 4.2418129444122314)
# Selected Parent 14: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.39500001072883606, 275994.0, 4.202924728393555)
# Selected Parent 15: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.4050000011920929, 275994.0, 4.281090497970581)
#
# --- Applying Crossover and Mutation ---
#
# Crossover Pair 1:
#   Before Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#
# Crossover Pair 4:
#   Before Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#
# Crossover Pair 5:
#   Before Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#
# Crossover Pair 7:
#   Before Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Crossover:
#     Child 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#
# Mutation for Offspring 9:
#   Before Mutation: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Mutation: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#
# Mutation for Offspring 12:
#   Before Mutation: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Mutation: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]
#
# --- Crossover and Mutation Complete ---
#
# -- Generation 3 --
# Evaluating individual 1: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 1 Results: Accuracy: 0.41999998688697815, Model Complexity: 275994, Training Time: 4.42868185043335
# Evaluating individual 2: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 2 Results: Accuracy: 0.3700000047683716, Model Complexity: 275994, Training Time: 4.225457668304443
# Evaluating individual 3: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 3 Results: Accuracy: 0.4050000011920929, Model Complexity: 275994, Training Time: 5.302920579910278
# Evaluating individual 4: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 4 Results: Accuracy: 0.38499999046325684, Model Complexity: 8395018, Training Time: 4.710057973861694
# Evaluating individual 5: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 5 Results: Accuracy: 0.3799999952316284, Model Complexity: 8395018, Training Time: 3.809335470199585
# Evaluating individual 6: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 6 Results: Accuracy: 0.41999998688697815, Model Complexity: 275994, Training Time: 5.01075553894043
# Evaluating individual 7: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 7 Results: Accuracy: 0.42500001192092896, Model Complexity: 275994, Training Time: 4.338979721069336
# Evaluating individual 8: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 8 Results: Accuracy: 0.36500000953674316, Model Complexity: 275994, Training Time: 7.604970693588257
# Evaluating individual 9: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 9 Results: Accuracy: 0.41499999165534973, Model Complexity: 275994, Training Time: 4.0827131271362305
# Evaluating individual 10: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 10 Results: Accuracy: 0.39500001072883606, Model Complexity: 275994, Training Time: 4.28583025932312
# Evaluating individual 11: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 11 Results: Accuracy: 0.38499999046325684, Model Complexity: 275994, Training Time: 7.242599010467529
# Evaluating individual 12: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]
# Individual 12 Results: Accuracy: 0.4449999928474426, Model Complexity: 4198922, Training Time: 4.5956573486328125
# Evaluating individual 13: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 13 Results: Accuracy: 0.38499999046325684, Model Complexity: 275994, Training Time: 7.212780237197876
# Evaluating individual 14: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 14 Results: Accuracy: 0.4099999964237213, Model Complexity: 275994, Training Time: 4.291647911071777
# Evaluating individual 15: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 15 Results: Accuracy: 0.375, Model Complexity: 275994, Training Time: 5.18870997428894
# Average Fitness: 0.39866666396458944
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}]]
# Lexicase selection in Generation 3:
# Selected Parent 1: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.38499999046325684, 8395018.0, 4.710057973861694)
# Selected Parent 2: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.36500000953674316, 275994.0, 7.604970693588257)
# Selected Parent 3: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}], Fitness: (0.4449999928474426, 4198922.0, 4.5956573486328125)
# Selected Parent 4: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}], Fitness: (0.4449999928474426, 4198922.0, 4.5956573486328125)
# Selected Parent 5: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.36500000953674316, 275994.0, 7.604970693588257)
# Selected Parent 6: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.36500000953674316, 275994.0, 7.604970693588257)
# Selected Parent 7: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}], Fitness: (0.4449999928474426, 4198922.0, 4.5956573486328125)
# Selected Parent 8: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.38499999046325684, 8395018.0, 4.710057973861694)
# Selected Parent 9: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}], Fitness: (0.4449999928474426, 4198922.0, 4.5956573486328125)
# Selected Parent 10: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.38499999046325684, 8395018.0, 4.710057973861694)
# Selected Parent 11: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}], Fitness: (0.4449999928474426, 4198922.0, 4.5956573486328125)
# Selected Parent 12: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.38499999046325684, 8395018.0, 4.710057973861694)
# Selected Parent 13: Architecture: [{'type': 'conv', 'filters': 64, 'activation': 'relu'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 16, 'activation': 'tanh'}], Fitness: (0.4449999928474426, 4198922.0, 4.5956573486328125)
# ...
# Individual 11 Results: Accuracy: 0.36000001430511475, Model Complexity: 8395018, Training Time: 4.280811071395874
# Evaluating individual 12: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 12 Results: Accuracy: 0.38999998569488525, Model Complexity: 8395018, Training Time: 4.54693341255188
# Evaluating individual 13: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 13 Results: Accuracy: 0.41499999165534973, Model Complexity: 8395018, Training Time: 4.216044902801514
# Evaluating individual 14: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 14 Results: Accuracy: 0.4050000011920929, Model Complexity: 8395018, Training Time: 3.9661879539489746
# Evaluating individual 15: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
# Individual 15 Results: Accuracy: 0.4099999964237213, Model Complexity: 8395018, Training Time: 4.781351089477539
# Average Fitness: 0.3963333328564962
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Best candidates: [[{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]]
# Lexicase selection in Generation 9:
# Selected Parent 1: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 2: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 3: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41499999165534973, 8395018.0, 5.050905466079712)
# Selected Parent 4: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 5: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 6: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 7: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 8: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41499999165534973, 8395018.0, 5.050905466079712)
# Selected Parent 9: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 10: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 11: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 12: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 13: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41499999165534973, 8395018.0, 5.050905466079712)
# Selected Parent 14: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
# Selected Parent 15: Architecture: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}], Fitness: (0.41999998688697815, 8395018.0, 3.7537333965301514)
#
# --- Applying Crossover and Mutation ---
#
# Crossover Pair 4:
#   Before Crossover:
#     Child 1: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Crossover:
#     Child 1: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#     Child 2: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#
# Mutation for Offspring 10:
#   Before Mutation: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
#   After Mutation: [{'type': 'dense', 'units': 256, 'activation': 'relu'}, {'type': 'conv', 'filters': 128, 'activation': 'tanh'}]
#
# --- Crossover and Mutation Complete ---
# Best architecture found: [{'type': 'conv', 'filters': 128, 'activation': 'tanh'}, {'type': 'dense', 'units': 256, 'activation': 'relu'}]
